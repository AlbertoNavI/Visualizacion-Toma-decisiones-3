# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
nombre = 'Beto'
print (nombre)
nombre
# %lsmagic
# %ls
# %pwd
# Out:
# Beto
# 00_00_binder.ipynb                    datasets/
# 00_00_primer_pasos.ipynb              README.md
# 01_01_data_types.ipynb                _read_me.txt
# 01_02_read_iloc_unique_groupby.ipynb  requirements.txt
# 01_03_data_wrangling.ipynb
# '/home/jovyan'

# %%
import numpy as np
n=50
np.random.rand(n)
# Out:
# array([0.28361102, 0.54217657, 0.7511289 , 0.01762128, 0.12484685,
#        0.62135715, 0.43929809, 0.08432483, 0.43459244, 0.04939109,
#        0.55754366, 0.1279132 , 0.41370083, 0.8278365 , 0.94295938,
#        0.88224357, 0.02571595, 0.20526833, 0.7782521 , 0.47232612,
#        0.93651134, 0.27495098, 0.39905979, 0.47338677, 0.07567486,
#        0.32664276, 0.77376332, 0.71245961, 0.76071883, 0.12620166,
#        0.78668422, 0.12702468, 0.4124927 , 0.44730155, 0.24465719,
#        0.25460544, 0.88854441, 0.86919007, 0.09182078, 0.54559864,
#        0.00342061, 0.12125287, 0.79319487, 0.52424511, 0.15214159,
#        0.48452539, 0.75425769, 0.76267169, 0.07773705, 0.52498673])

# %%
import math 
type(4.2)
# Out:
# float

# %%
type('badabing')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
an_array = [1,2,3,4,5,6,7]
an_array
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
suma=sum(an_array)
suma
# Out:
# 28

# %%
mean_array = suma/len(an_array)
mean_array
# Out:
# 4.0

# %%
6**2
# Out:
# 36

# %%
6*10**(-1)
# Out:
# 0.6000000000000001

# %%
math.pi*2
# Out:
# 6.283185307179586

# %%
otra_array = [2,math.pi,3/5,'otra array']
otra_array
# Out:
# [2, 3.141592653589793, 0.6, 'otra array']

# %%
x=18
y=15
if x<y: 
    print('{} es menor que {}'.format(x, y))
else:
    print('{} es menor que {}'.format(y, x))
# Out:
# 15 es menor que 18

# %%
my_list = [True, 6<5, 1==3, None is None]
my_list
# Out:
# [True, False, False, True]

# %%
for i in my_list:
    print('{} \t {}'. format(i, type(i)))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
for i in my_list:
    print(i,' \t', type(i))
# Out:
# True  	 <class 'bool'>
# False  	 <class 'bool'>
# False  	 <class 'bool'>
# True  	 <class 'bool'>

# %%
none_list=[None]*5
none_list
# Out:
# [None, None, None, None, None]

# %%
len(none_list)
# Out:
# 5

# %%
una_lista= ['pos_0','uno','dos','tres','cuatro','quinto']
len(una_lista)
# Out:
# 6

# %%
una_lista[3]
# Out:
# 'tres'

# %%
una_lista[0:3]
# Out:
# ['pos_0', 'uno', 'dos']

# %%
una_lista[-2:]
# Out:
# ['cuatro', 'quinto']

# %%
una_lista[5]
# Out:
# 'quinto'

# %%
np.dot(3,4)
# Out:
# 12

# %%
np.dot([2j,3j],[2j,3j])
# Out:
# (-13+0j)

# %%
import pandas as pd

# %%
data_set = 'datasets/Cartwheeldata.csv'
df= pd.read_csv(data_set)
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.head(13)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
index_list = list(df.columns)
index_list.sort()
index_list
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
for i in df.columns:
    print(i)
# Out:
# ID
# Age
# Gender
# GenderGroup
# Glasses
# GlassesGroup
# Height
# Wingspan
# CWDistance
# Complete
# CompleteGroup
# Score

# %%
x= df['Height']
print(x)
print(type(x))
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
y= df[['Height']]
print(y)
print(type(y))
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00
# <class 'pandas.core.frame.DataFrame'>

# %%
df[['Height','Gender']]
# Out:
#     Height Gender
# 0    62.00      F
# 1    62.00      F
# 2    66.00      F
# 3    64.00      F
# 4    73.00      M
# 5    75.00      M
# 6    75.00      M
# 7    65.00      F
# 8    74.00      M
# 9    63.00      F
# 10   69.50      M
# 11   62.75      F
# 12   65.00      F
# 13   61.50      F
# 14   73.00      M
# 15   71.00      M
# 16   61.50      F
# 17   66.00      M
# 18   70.00      M
# 19   68.00      F
# 20   69.00      M
# 21   71.00      M
# 22   70.00      M
# 23   69.00      M
# 24   65.00      F

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[1:4] #rowstart:row end, column_start:column_end
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.loc[:3,'GenderGroup':'Complete']
# Out:
#    GenderGroup Glasses  GlassesGroup  Height  Wingspan  CWDistance Complete
# 0            1       Y             1    62.0      61.0          79        Y
# 1            1       Y             1    62.0      60.0          70        Y
# 2            1       Y             1    66.0      64.0          85        Y
# 3            1       N             0    64.0      63.0          87        Y

# %%
df.iloc[:3,1:4] # iloc con indices
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1
# 2   33      F            1

# %%
df.Height.unique()
# Out:
# array([62.  , 66.  , 64.  , 73.  , 75.  , 65.  , 74.  , 63.  , 69.5 ,
#        62.75, 61.5 , 71.  , 70.  , 68.  , 69.  ])

# %%
df.groupby(['Height','GenderGroup']).size()
# Out:
# Height  GenderGroup
# 61.50   1              2
# 62.00   1              2
# 62.75   1              1
# 63.00   1              1
# 64.00   1              1
# 65.00   1              3
# 66.00   1              1
#         2              1
# 68.00   1              1
# 69.00   2              2
# 69.50   2              1
# 70.00   2              2
# 71.00   2              2
# 73.00   2              2
# 74.00   2              1
# 75.00   2              2
# dtype: int64

# %%
df.groupby(['Gender','GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64
