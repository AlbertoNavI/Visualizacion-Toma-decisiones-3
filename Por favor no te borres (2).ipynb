# %%
import pandas as pd
import numpy as np
from scipy import stats
from pylab import *
import seaborn as sns

ad = pd.read_csv('datasets/tips.csv')
ad.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
ad = pd.read_csv('datasets/tips.csv')

sns.lmplot( x='tip', y='total_bill', data = ad)

# %%
sns.boxplot( x='total_bill', data = ad)

# %%
sns.boxplot( x='tip', data = ad)

# %%
pd.pivot_table(ad,index='size',columns='tip',values='total_bill')
